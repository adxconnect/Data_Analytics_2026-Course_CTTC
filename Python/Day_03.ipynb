# %%
# %run ./Day_02.ipynb
# Out:
# Hello
# [1 3 5 7 9]
# [[1 3]
#  [2 4]]
# [[5 7]
#  [8 9]]
# C:\Users\softl\AppData\Local\Temp\ipykernel_12628\2626738034.py:1: RuntimeWarning: divide by zero encountered in divide
#   np.divide(a,b)
# C:\Users\softl\AppData\Local\Temp\ipykernel_12628\3371653468.py:2: RuntimeWarning: divide by zero encountered in floor_divide
#   np.floor_divide(a,b)
# C:\Users\softl\AppData\Local\Temp\ipykernel_12628\3052545775.py:2: RuntimeWarning: divide by zero encountered in remainder
#   np.mod(a,b)
# C:\Users\softl\AppData\Local\Temp\ipykernel_12628\1843698144.py:2: RuntimeWarning: divide by zero encountered in divmod
#   np.divmod(a,b)
# C:\Users\softl\AppData\Local\Temp\ipykernel_12628\4069035518.py:2: DeprecationWarning: Arrays of 2-dimensional vectors are deprecated. Use arrays of 3-dimensional vectors instead. (deprecated in NumPy 2.0)
#   np.cross(a,b)

# %% [markdown]
# DAY : 03 Date : 20th Jan 2026

# %% [markdown]
# Pandas is a pythons's library which is use to analyze and manipulate the data. It is also use to read and create datasets.
#
# Panda is of two types:
# ---> Series(Single Column)
# ---> DataFrame(Multiple Coloumns)

# %%
import pandas as pd
#Creating series
s=pd.Series((10,20))
s
# Out:
# 0    10
# 1    20
# dtype: int64

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s=pd.Series(['a','b','c','d','e'],index=[10,20,30,40,50])
s
# Out:
# 10    a
# 20    b
# 30    c
# 40    d
# 50    e
# dtype: object

# %%
#Slicing
s[1::2]
# Out:
# 20    b
# 40    d
# dtype: object

# %%
s[::-1]
# Out:
# 50    e
# 40    d
# 30    c
# 20    b
# 10    a
# dtype: object

# %%
s=pd.Series(['a','b','c','d','e'],index=np.arange(5,10))
s
# Out:
# 5    a
# 6    b
# 7    c
# 8    d
# 9    e
# dtype: object

# %%
#Tuple to Series
t=pd.Series((100,200,300,400,500))
t
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# 4    500
# dtype: int64

# %%
#indexing
t[2]
# Out:
# np.int64(300)

# %%
t[::-1]
# Out:
# 4    500
# 3    400
# 2    300
# 1    200
# 0    100
# dtype: int64

# %%
#Set to Series
s=pd.Series(list({35,35,35,10,10,25}))
s
# Out:
# 0    25
# 1    10
# 2    35
# dtype: int64

# %%
#Dictionary to series
d=pd.Series({'a':10,'b':20,'c':30})
d
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
import pandas as pd

# %%
#Creation of DataFrame
d = {'Name':['Aniket','Sourita','Trisha','Simran'],
'Roll':[111,112,113,114],
'Marks':[95,88,76,89]}
d
# Out:
# {'Name': ['Aniket', 'Sourita', 'Trisha', 'Simran'],
#  'Roll': [111, 112, 113, 114],
#  'Marks': [95, 88, 76, 89]}

# %%
df = pd.DataFrame(d)
df
# Out:
#       Name  Roll  Marks
# 0   Aniket   111     95
# 1  Sourita   112     88
# 2   Trisha   113     76
# 3   Simran   114     89

# %% [markdown]
# pandas.core.frame.DataFrame

# %%
#indexing
df.Name[2]
# Out:
# 'Trisha'

# %%
df.Marks[3]
# Out:
# np.int64(89)

# %%
#slicing
#iloc - integer location(used for slicing)
df.iloc[::, ::]
# Out:
#       Name  Roll  Marks
# 0   Aniket   111     95
# 1  Sourita   112     88
# 2   Trisha   113     76
# 3   Simran   114     89

# %%
#Reverse
df.iloc[::-1, ::-1]
# Out:
#    Marks  Roll     Name
# 3     89   114   Simran
# 2     76   113   Trisha
# 1     88   112  Sourita
# 0     95   111   Aniket

# %%
df=df.rename(columns={'Name':'Stu_Name'})
df
# Out:
#   Stu_Name  Roll  Marks
# 0   Aniket   111     95
# 1  Sourita   112     88
# 2   Trisha   113     76
# 3   Simran   114     89
