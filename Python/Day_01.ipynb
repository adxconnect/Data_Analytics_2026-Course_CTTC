# %% [markdown]
# **DAY 01** : 17th Jan 2026

# %% [markdown]
# # 🌟NumPy - "Numerical Python"
# <pre><b>Numpy  is a Python's library which is used to perform different mathematical operations on arrays.
#
# Array is denoted with "[]". It is ordered (index position is fixed), mutable (items can be modified) and homogenous (similar datatypes) colection of items.</pre>

# %%
print("Hello")
# Out:
# Hello

# %%
#to import numpy
import numpy as np

# %%
#to check the version of numpy
np.__version__
# Out:
# '2.3.5'

# %% [markdown]
# # h1
# ## h2
# ### h3
# #### h4
# ##### h5
# ###### h6
# <pre> 🔴 Python is a programming Language
# For installation '!pip install numpy' for numpy</pre>

# %%
#Creating 1D Array.
a=np.array([1,3,5,7,9])
print(a)
a
# Out:
# [1 3 5 7 9]
# array([1, 3, 5, 7, 9])

# %%
type(a) #ndarray: n - dimentional array
# Out:
# numpy.ndarray

# %%
#dtype='<U32' - It defines that the characters and elements must be less that 32 bit max.
a=np.array([20,'tree',3.5,True])
a
# Out:
# array(['20', 'tree', '3.5', 'True'], dtype='<U32')

# %%
a=np.array(['cat','tree','dog','aeroplane','11','25'],dtype='<U3')
a
# Out:
# array(['cat', 'tre', 'dog', 'aer', '11', '25'], dtype='<U3')

# %%
a=np.array([20,3.5,55,True])
a
# Out:
# array([20. ,  3.5, 55. ,  1. ])

# %%
#Tuple to Array
t=np.array((10,20,30,50))
t
# Out:
# array([10, 20, 30, 50])

# %%
#Set to Array
s=np.array({1,1,1,1,8,8,8,4,4,4})
s
# Out:
# array({8, 1, 4}, dtype=object)

# %%
#Dict to Array
d=np.array({'a':1,'b':2,'c':3})
d
# Out:
# array({'a': 1, 'b': 2, 'c': 3}, dtype=object)

# %%
#Creating 2D-Array
b=np.array([[1,3,5],[2,4,6]])
b
# Out:
# array([[1, 3, 5],
#        [2, 4, 6]])
